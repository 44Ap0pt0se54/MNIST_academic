# %%
# !git clone https://github.com/44Ap0pt0se54/MNIST_academic.git
                                                                  # Run only once this section to import the resources
from MNIST_academic import Model

# %%
MyModel = Model.Model("CNN")      # Suitable strings: {"DNN", "CNN", "ResNet"}

# %%
MyModel.test_model()

# %%
MyModel.feature_visualization(1)      # This method is only available for CNN and ResNet !
                                      # First parameter is the layer level, ranging from 0 to 4
